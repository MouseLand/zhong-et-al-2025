# %% [markdown]
# # This notebook is for plotting all figures

# %%
import sys
import numpy as np
import os
import utils
from matplotlib import pyplot as plt
from importlib import reload
import fig1, fig2
root = r'D:\Results\Zhong-et-al-2025'

# %%
dat = fig1.load_fig1_dat(root = r'D:\Results\Zhong-et-al-2025')
fig1.plot_fig1(dat, root)

# %%
dat = fig2.load_fig2_dat(root = r'D:\Results\Zhong-et-al-2025')
fig2.plot_fig1(dat, root)
# Out:
# C:\Users\zhongl\AppData\Local\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\zhongl\AppData\Local\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\zhongl\AppData\Local\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\zhongl\AppData\Local\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# coding direction of leaf1 - circle1
# coding direction of leaf1 - circle1
# coding direction of leaf1 - circle1
# coding direction of leaf1 - circle1
# D:\Codes\zhong-et-al-2025\utils.py:233: RuntimeWarning: Mean of empty slice.
#   resp_diff_u[m, a, s] = resp_diff[m, a, s].mean(0)
# ...
